# %%
from banglatts import BanglaTTS
import time
import os

lyrics = [
    "যদি বিরহ থাকে আমিও থাকি",
    "কে বলো শেষ হবে আগে?",
    "কেন যে এত ভালোবাসা মরে যায়",
    "শুধু সময় মনে রাখে",
    "এত শূন্যতা এ মনে রাখি যে আমি",
    "দেখে না কেউ তো আর, বলে এ সবই পাগলামি",
    "কাটে না যামিনী, বিরহ যেন কেটে যায়",
    "থামে না বরষা, তোমারে ডাকি যে আমি",
    "(আর)"
]

def clear_screen():
    os.system('cls' if os.name == 'nt' else 'clear')

def display_lyrics(lyrics):
    clear_screen()
    print("Bangla Song Lyrics:\n")
    for line in lyrics:
        for char in line:
            print(char, end='', flush=True)
            time.sleep(0.09)
        print()
        time.sleep(1.2)

if __name__ == "__main__":
    tts = BanglaTTS()
    display_lyrics(lyrics)
    tts.text_to_speech("\n".join(lyrics))
# Out:
# Using cache found in C:\Users\chakr\bangla_tts\snakers4_silero-models_master
# Bangla Song Lyrics:
#
# যদি বিরহ থাকে আমিও থাকি
# কে বলো শেষ হবে আগে?
# কেন যে এত ভালোবাসা মরে যায়
# শুধু সময় মনে রাখে
# এত শূন্যতা এ মনে রাখি যে আমি
# দেখে না কেউ তো আর, বলে এ সবই পাগলামি
# কাটে না যামিনী, বিরহ যেন কেটে যায়
# থামে না বরষা, তোমারে ডাকি যে আমি
# (আর)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 33
#      31 tts = BanglaTTS()
#      32 display_lyrics(lyrics)
# ---> 33 tts.text_to_speech("\n".join(lyrics))
#
# AttributeError: 'BanglaTTS' object has no attribute 'text_to_speech'

# %%
import pygame
from gtts import gTTS
import time
import os

lyrics = [
    "যদি বিরহ থাকে আমিও থাকি",
    "কে বলো শেষ হবে আগে?",
    "কেন যে এত ভালোবাসা মরে যায়",
    "শুধু সময় মনে রাখে",
    "এত শূন্যতা এ মনে রাখি যে আমি",
    "দেখে না কেউ তো আর, বলে এ সবই পাগলামি",
    "কাটে না যামিনী, বিরহ যেন কেটে যায়",
    "থামে না বরষা, তোমারে ডাকি যে আমি",
    "(আর)"
]

def clear_screen():
    os.system('cls' if os.name == 'nt' else 'clear')

def display_lyrics(lyrics):
    clear_screen()
    print("Bangla Song Lyrics:\n")
    for line in lyrics:
        for char in line:
            print(char, end='', flush=True)
            time.sleep(0.09)
        print()
        time.sleep(1.2)

if __name__ == "__main__":
    display_lyrics(lyrics)

    # Combine lyrics into one spoken block
    song_text = "\n".join(lyrics)

    # Convert to Bangla speech
    tts = gTTS(text=song_text, lang='bn', slow=False)
    tts.save("song.mp3")

    print("\nNow playing the sung lyrics 🎵 ...")
    playsound("song.mp3")
# Out:
# Bangla Song Lyrics:
#
# য
# দি বিরহ থাকে আমিও থাকি
# কে বলো শেষ হবে আগে?
# কেন যে এত ভালোবাসা মরে যায়
# শুধু সময় মনে রাখে
# এত শূন্যতা এ মনে রাখি যে আমি
# দেখে না কেউ তো আর, বলে এ সবই পাগলামি
# কাটে না যামিনী, বিরহ যেন কেটে যায়
# থামে না বরষা, তোমারে ডাকি যে আমি
# (আর)
#
# Now playing the sung lyrics 🎵 ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 42
#      39 tts.save("song.mp3")
#      41 print("\nNow playing the sung lyrics 🎵 ...")
# ---> 42 playsound("song.mp3")
#
# NameError: name 'playsound' is not defined
